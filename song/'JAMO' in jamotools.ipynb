# %%
import numpy as np
import jamotools

# %%
meta_path = "D:/korean-single-speaker-speech-dataset/transcript.v.1.2.txt"
data_folder = "D:/korean-single-speaker-speech-dataset/kss"

with open(meta_path, encoding='utf-8') as f:
    metadata = np.array([line.strip().split('|') for line in f])

# %%
split_jamo = list(map(jamotools.split_syllables, metadata[:, 2]))
print("{}: {}".format(split_jamo[0], len(split_jamo[0])))
print()

join_jamo = list(map(jamotools.join_jamos, metadata[:, 3]))
print("{}: {}".format(join_jamo[0], len(join_jamo[0])))
print()

for i in range(5):
    print(metadata[0, 3][i])
    print(hex(ord(metadata[0, 3][i])))
    
print()

for i in range(5):
    print(split_jamo[0][i])
    print(hex(ord(split_jamo[0][i])))
    
print()

for i in range(5):
    print(metadata[0, 2][i])
    print(hex(ord(metadata[0, 2][i])))
    
print()

for i in range(5):
    print(join_jamo[0][i])
    print(hex(ord(join_jamo[0][i])))
# Out:
# ㄱㅡㄴㅡㄴ ㄱㅙㄴㅊㅏㄶㅇㅡㄴ ㅊㅓㄱㅎㅏㄹㅕㄱㅗ ㅇㅐㅆㅡㄴㅡㄴ ㄱㅓㅅ ㄱㅏㅌㅇㅏㅆㄷㅏ.: 47
#
# 그는 괜찮은 척하려고 애쓰는 것 같았다.: 22
#
# ᄀ
# 0x1100
# ᅳ
# 0x1173
# ᄂ
# 0x1102
# ᅳ
# 0x1173
# ᆫ
# 0x11ab
#
# ㄱ
# 0x3131
# ㅡ
# 0x3161
# ㄴ
# 0x3134
# ㅡ
# 0x3161
# ㄴ
# 0x3134
#
# 그
# 0xadf8
# 는
# 0xb294
#
# 0x20
# 괜
# 0xad1c
# 찮
# 0xcc2e
#
# 그
# 0xadf8
# 는
# 0xb294
#
# 0x20
# 괜
# 0xad1c
# 찮
# 0xcc2e

# %%
split_jamo = list(map(jamotools.split_syllables, metadata[:, 2], ['JAMO']))
print("{}: {}".format(split_jamo[0], len(split_jamo[0])))
print()

join_jamo = list(map(jamotools.join_jamos, metadata[:, 3]))
print("{}: {}".format(join_jamo[0], len(join_jamo[0])))
print()

for i in range(5):
    print(metadata[0, 3][i])
    print(hex(ord(metadata[0, 3][i])))
    
print()

for i in range(5):
    print(split_jamo[0][i])
    print(hex(ord(split_jamo[0][i])))
    
print()

for i in range(5):
    print(metadata[0, 2][i])
    print(hex(ord(metadata[0, 2][i])))
    
print()

for i in range(5):
    print(join_jamo[0][i])
    print(hex(ord(join_jamo[0][i])))
# Out:
# 그는 괜찮은 척하려고 애쓰는 것 같았다.: 47
#
# 그는 괜찮은 척하려고 애쓰는 것 같았다.: 22
#
# ᄀ
# 0x1100
# ᅳ
# 0x1173
# ᄂ
# 0x1102
# ᅳ
# 0x1173
# ᆫ
# 0x11ab
#
# ᄀ
# 0x1100
# ᅳ
# 0x1173
# ᄂ
# 0x1102
# ᅳ
# 0x1173
# ᆫ
# 0x11ab
#
# 그
# 0xadf8
# 는
# 0xb294
#
# 0x20
# 괜
# 0xad1c
# 찮
# 0xcc2e
#
# 그
# 0xadf8
# 는
# 0xb294
#
# 0x20
# 괜
# 0xad1c
# 찮
# 0xcc2e
